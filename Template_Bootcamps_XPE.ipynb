# %% [markdown]
# <a href="https://colab.research.google.com/github/simonfriedmann/raw_noteboks_TEMPLATES/blob/main/Template_Bootcamps_XPE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modulo 1

# %% [markdown]
# ### Plano de ensino

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Aulas Interativas

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio

# %% [markdown]
# # Modulo 2

# %% [markdown]
# ### Plano de ensino

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Aulas Interativas

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio

# %% [markdown]
# # Modulo 3

# %% [markdown]
# ### Plano de ensino

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Aulas Interativas

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio

# %% [markdown]
# # Modulo 4

# %% [markdown]
# ### Plano de ensino

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Aulas Interativas

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio

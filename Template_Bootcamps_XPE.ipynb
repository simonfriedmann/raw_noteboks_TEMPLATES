# %% [markdown]
# <a href="https://colab.research.google.com/github/simonfriedmann/Colabs_Templates/blob/main/Template_Bootcamps_XPE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modulo 1

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio

# %% [markdown]
# # Modulo 2

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio

# %% [markdown]
# # Modulo 3

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio

# %% [markdown]
# # Modulo 4

# %% [markdown]
# ### Video Aulas

# %% [markdown]
# ### Apostila

# %% [markdown]
# ### Trabalho pratico

# %% [markdown]
# ### Desafio
